# %%
import os 
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tables = {f.replace('.csv', ''): f for f in os.listdir('.') if f.endswith('.csv')}

# %%
for table_name, file_path in tables.items():
    print(table_name)
    tables[table_name] = pd.read_csv(file_path)
    print(tables[table_name].shape)
# Out:
# HumanResources.Department
# (16, 4)
# HumanResources.EmployeeDepartmentHistory
# (100, 6)
# HumanResources.Employee
# (100, 16)
# HumanResources.EmployeePayHistory
# (100, 5)
# HumanResources.JobCandidate
# (13, 4)
# HumanResources.Shift
# (3, 5)

# %%
print()
# Out:
# {'HumanResources.Department':     DepartmentID                        Name  \
#  0              1                 Engineering
#  1              2                 Tool Design
#  2              3                       Sales
#  3              4                   Marketing
#  4              5                  Purchasing
#  5              6    Research and Development
#  6              7                  Production
#  7              8          Production Control
#  8              9             Human Resources
#  9             10                     Finance
#  10            11        Information Services
#  11            12            Document Control
#  12            13           Quality Assurance
#  13            14  Facilities and Maintenance
#  14            15      Shipping and Receiving
#  15            16                   Executive
#
#                                 GroupName         ModifiedDate
#  0               Research and Development  2002-06-01 00:00:00
# ...
